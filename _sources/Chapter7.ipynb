# %% [markdown]
# # Μόνιμη Μεταφορά & Διάχυση
#
# **Περίληψη**. Σε αυτό το κεφάλαιο περιγράφεται η εξίσωση μόνιμης μεταφοράς και διάχυσης σε μια διάσταση. Εισάγεται η διακριτή μορφή με την μέθοδο των ΠΔ καθώς και με τη μέθοδο των ΠΟ. Περιγράφεται το σχήμα ανάντη διαφορών (upwind). Ακολουθεί η επέκταση της μεθοδολογίας στις δύο διαστάσεις. Το κεφάλαιο κλείνει με αναλυτικές εφαρμογές και ασκήσεις προς λύση με υπόδειξη για τα βασικά βήματα επίλυσης τους.
#
# ## Εξίσωση μόνιμης μεταφοράς και διάχυσης σε μια διάσταση
#
# ## Σχήμα κεντρικών πεπερασμένων διαφορών
#
# ## Σχήμα ανάντη διαφορών (upwind)
#
# ## Επέκταση στις δύο διαστάσεις
#
# ## Εφαρμογές & ασκήσεις
