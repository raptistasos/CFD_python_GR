# %% [markdown]
# # Η εξίσωση Διάχυσης
#
# **Περίληψη**. Στην πρώτη ενότητα αυτού του κεφαλαίου η μεθοδολογία ξεκινά με την απλούστερη ΜΔΕ, την εξίσωση Διάχυσης. Περιγράφεται το πρόβλημα αρχικών-συνοριακών τιμών για την εξίσωση διάχυσης σε μια διάσταση. Ακολουθεί η άμεση και πεπλεγμένη μέθοδος του Euler και το σχήμα των Crank –Nicolson. Εισάγεται ο κανόνας θ και το αριθμητικό σχήμα του Richardson, καθώς και το σχήμα των Dufort-Frankel. Ακολουθεί η επέκταση της μεθοδολογίας στις δύο διαστάσεις. Το κεφάλαιο κλείνει με αναλυτικές εφαρμογές και ασκήσεις προς λύση με υπόδειξη για τα βασικά βήματα επίλυσης τους.
#
# ## Η εξίσωση διάχυσης σε μια διάσταση
#
# ## Το πρόβλημα αρχικών-συνοριακών τιμών για διάχυση σε μια διάσταση
#
# ## Άμεσο και πεπλεγμένο σχήμα του Euler
#
# ## Το σχήμα των Crank-Nicolson
#
# ## Ο κανόνας θ
#
# ## Αριθμητικό σχήμα του Richardson
#
# ## Τύπος των Dufort-Frankel
#
# ## Επέκταση στις 2 διαστάσεις
#
# ## Εφαρμογές & ασκήσεις
